# %%
from python_speech_features import mfcc
from CQCC.cqcc import cqcc
import scipy.io.wavfile as wav
import soundfile as sf
import os
import numpy as np
import pickle
import argparse
import sys
import time
import multiprocessing as mp
import warnings
import pandas as pd
from sklearn.mixture import GaussianMixture as GMM

# %%
def chunks(lst, n):
#"""Yield successive n-sized chunks from lst."""
    list = []
    for i in range(0, len(lst), n):
        list.append(lst[i:i + n])
    return list

# %%
data_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_train/sample_train'
label_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.train.trn.txt'
output_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_train/'

# %%
total_files = len(os.listdir(data_path))
total_files

round(total_files/4)
# Out:
# 25

# %%
file_lists = chunks(os.listdir(data_path),25)
file_lists
# Out:
# [['LA_T_1014095.flac',
#   'LA_T_1029929.flac',
#   'LA_T_1013068.flac',
#   'LA_T_1022109.flac',
#   'LA_T_1028046.flac',
#   'LA_T_1023667.flac',
#   'LA_T_1034356.flac',
#   'LA_T_1000824.flac',
#   'LA_T_1000648.flac',
#   'LA_T_1009193.flac',
#   'LA_T_1030180.flac',
#   'LA_T_2361751.flac',
#   'LA_T_1011022.flac',
#   'LA_T_1010799.flac',
#   'LA_T_1004631.flac',
#   'LA_T_1028533.flac',
#   'LA_T_1011920.flac',
#   'LA_T_1005349.flac',
#   'LA_T_1001074.flac',
#   'LA_T_1029621.flac',
#   'LA_T_1021790.flac',
#   'LA_T_1019645.flac',
#   'LA_T_1026106.flac',
#   'LA_T_1030482.flac',
#   'LA_T_1029007.flac'],
#  ['LA_T_1004407.flac',
#   'LA_T_1006969.flac',
#   'LA_T_1021749.flac',
#   'LA_T_1026130.flac',
#   'LA_T_1025399.flac',
#   'LA_T_1010137.flac',
#   'LA_T_1000137.flac',
#   'LA_T_1017164.flac',
#   'LA_T_1010025.flac',
#   'LA_T_1027268.flac',
#   'LA_T_1035039.flac',
#   'LA_T_1026727.flac',
#   'LA_T_1033159.flac',
#   'LA_T_1017386.flac',
# ...

# %%
def process_sound(filename):
    print(filename)

# %%
print("Number of processors: ", mp.cpu_count())
# Out:
# Number of processors:  4

# %%
pool = mp.Pool(mp.cpu_count())
file_lists = chunks(os.listdir(data_path),2)
results = pool.map(process_sound, [row for row in file_lists])

pool.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-8fe2952b0b36> in <module>
#       1 pool = mp.Pool(mp.cpu_count())
#       2 file_lists = chunks(os.listdir(data_path),2)
# ----> 3 results = pool.map(process_sound, [row for row in file_lists])
#       4
#       5 pool.close()
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ...

# %%
import pickle

# %%
label_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.train.trn.txt'
data_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_train/sample_train'
filename2label = {}
for line in open(label_path):
    line = line.split()
    filename, label = line[1], line[-1]
    filename2label[filename] = label

# %%
type(data[0][0])
# Out:
# tuple

# %%
flatten = lambda t: [item for data in t for item in data]
# Out:
# 100

# %%
data = pickle.load(open('/Users/asimadnan/Desktop/Mres/Experiments/testfiles/la_dev_mfcc_cqcc.pkl','rb'))
# for feat_cqcc, feat_mfcc, label, filename in data:
#     # feature selection
#     print(feat_cqcc)
#     print(feat_mfcc)
#     print(label)
#     print(filename)
#     break

# %%
# chunk size 25, total time = 74 sec

# %%
len(data)
# Out:
# 24986

# %%
d = data[400:500]

# %%
12973.868796231/24986
# Out:
# 0.5192455293456736

# %%
time_list = []
time_list.append([2,5])
time_list
# Out:
# [[2, 5]]

# %%
print('total_files,','Input Chunk Size,','total Chunks,','total time')
timeee = [[100, 2, 50, 62.678468432], [100, 4, 25, 70.29705011499999], [100, 6, 17, 68.383582563], [100, 8, 13, 72.17383657099998], [100, 10, 10, 78.09945650700001], [100, 12, 9, 76.57388660999999], [100, 14, 8, 76.59905989499998], [100, 16, 7, 76.56350377800004], [100, 18, 6, 76.64314643], [100, 20, 5, 83.150412673], [100, 22, 5, 79.01533577499993], [100, 24, 5, 84.58491776400001], [100, 26, 4, 86.48939740499998], [100, 28, 4, 87.91821308599992], [100, 30, 4, 80.50912069700007], [100, 32, 4, 95.53424700999994], [100, 34, 3, 109.93023481399996], [100, 36, 3, 90.16819629600013], [100, 38, 3, 99.56177691300013], [100, 40, 3, 149.62133563899988], [100, 42, 3, 135.55788136900014], [100, 44, 3, 76.08604159900005], [100, 46, 3, 73.35683923800002], [100, 48, 3, 76.672087036]]
[[100, 2, 50, 62.678468432], [100, 4, 25, 70.29705011499999], [100, 6, 17, 68.383582563], [100, 8, 13, 72.17383657099998], [100, 10, 10, 78.09945650700001], [100, 12, 9, 76.57388660999999], [100, 14, 8, 76.59905989499998], [100, 16, 7, 76.56350377800004], [100, 18, 6, 76.64314643], [100, 20, 5, 83.150412673], [100, 22, 5, 79.01533577499993], [100, 24, 5, 84.58491776400001], [100, 26, 4, 86.48939740499998], [100, 28, 4, 87.91821308599992], [100, 30, 4, 80.50912069700007], [100, 32, 4, 95.53424700999994], [100, 34, 3, 109.93023481399996], [100, 36, 3, 90.16819629600013], [100, 38, 3, 99.56177691300013], [100, 40, 3, 149.62133563899988], [100, 42, 3, 135.55788136900014], [100, 44, 3, 76.08604159900005], [100, 46, 3, 73.35683923800002], [100, 48, 3, 76.672087036]]
# Out:
# total_files, Input Chunk Size, total Chunks, total time
# [[100, 2, 50, 62.678468432],
#  [100, 4, 25, 70.29705011499999],
#  [100, 6, 17, 68.383582563],
#  [100, 8, 13, 72.17383657099998],
#  [100, 10, 10, 78.09945650700001],
#  [100, 12, 9, 76.57388660999999],
#  [100, 14, 8, 76.59905989499998],
#  [100, 16, 7, 76.56350377800004],
#  [100, 18, 6, 76.64314643],
#  [100, 20, 5, 83.150412673],
#  [100, 22, 5, 79.01533577499993],
#  [100, 24, 5, 84.58491776400001],
#  [100, 26, 4, 86.48939740499998],
#  [100, 28, 4, 87.91821308599992],
#  [100, 30, 4, 80.50912069700007],
#  [100, 32, 4, 95.53424700999994],
#  [100, 34, 3, 109.93023481399996],
#  [100, 36, 3, 90.16819629600013],
#  [100, 38, 3, 99.56177691300013],
#  [100, 40, 3, 149.62133563899988],
#  [100, 42, 3, 135.55788136900014],
#  [100, 44, 3, 76.08604159900005],
#  [100, 46, 3, 73.35683923800002],
#  [100, 48, 3, 76.672087036]]

# %%
data_sample = '/Users/asimadnan/Desktop/Mres/Experiments/testfiles/04-04-2021_15-09_dev_1.pkl'

# %%
def extract_feature(pkl_path,feature_type):
    max_len = 50  # 1.25 seconds  # check the timesteps of cqcc and mfcc 
    X = []
    y = []
    i=0
    with open(pkl_path, 'rb') as infile:
        data = pickle.load(infile)
        for feat_cqcc, feat_mfcc, label,filename in data:

            features = []
            feature_block = ''
           
            if feature_type == 'mfcc':
                feature_block = feat_mfcc
            elif feature_type == 'cqcc':
                
                feature_block = feat_cqcc


            if len(feature_block) > max_len:
                features = feature_block[:max_len]
            elif len(feature_block) < max_len:
                features = np.concatenate((feature_block, np.array([[0.]*num_dim]*(max_len-len(feature_block)))), axis=0)
            
            i+=1
            X.append(features.reshape(-1))
            y.append([label,filename])
        return X,y

# %%
X,y = extract_feature(data_sample,'cqcc')
data_cqcc = np.append(np.array(X),np.array(y),1)

# %%
pd.DataFrame(data_cqcc).to_csv("test.csv")

# %%
pd.DataFrame(data_cqcc)
# Out:
#                   0                    1                    2     \
# 0   -499.6327213616569   -533.3796955263269    -558.287298630881
# 1   -437.9251837468175   -467.5560885394292  -489.44369101138426
# 2  -459.66956922881303  -490.75366392580463    -513.704860797386
# 3   -611.9361772573278   -653.1426047560257   -683.5511341142098
# 4   -426.6186233438946   -455.5853891396558    -477.009201733706
# 5     -562.64966720095   -600.3901976028659   -628.1811318757916
# 6   -549.6284141870779   -586.9864782401293    -614.708097013891
#
#                   3                    4                    5     \
# 0   -574.2434965406399    -581.646475908288   -581.3570672448938
# 1   -503.4844010104992   -510.0215765704684  -509.80439245980875
# 2   -528.4165585549708   -535.2519060476723   -535.0003703431338
# 3   -703.0385653725765   -712.1034241737169   -711.8064112568557
# 4  -490.77790700657516  -497.21290009673265  -497.02954186277935
# ...

# %%
y
y_1=np.array(y)
y_1[:,1]
# Out:
# array(['LA_D_1099405', 'LA_D_9330492', 'LA_D_1364611', 'LA_D_3986002',
#        'LA_D_3411825', 'LA_D_8173305', 'LA_D_6027798'], dtype='<U12')

# %%
X
X_1=np.array(X)
X_1.shape
# Out:
# (7, 3000)

# %%
data_cqcc = np.append(X_1,y_1,1)
data_cqcc.shape
# Out:
# (7, 3002)

# %%
d
# Out:
# [(array([[-6.41058952e+02, -6.84246515e+02, -7.16078042e+02, ...,
#           -1.33335476e+00, -1.35609495e+00, -1.38193288e+00],
#          [ 4.74699924e+00,  5.06181341e+00,  5.28692289e+00, ...,
#           -2.98283630e+00, -3.03519820e+00, -3.09488159e+00],
#          [-1.10741354e+01, -1.18301934e+01, -1.24137009e+01, ...,
#           -3.89770710e+00, -3.96682444e+00, -4.04564951e+00],
#          ...,
#          [ 5.47826485e-05,  7.46745234e-05,  8.74657860e-05, ...,
#            2.18652526e-07, -3.54089894e-07, -9.15495513e-07],
#          [-3.14446321e-05, -4.65273964e-05, -5.64856032e-05, ...,
#            2.33922486e-07, -3.28666451e-07, -8.80630189e-07],
#          [-7.29279031e-05, -1.01359083e-04, -1.20196691e-04, ...,
#            1.72749807e-07, -2.95723008e-07, -7.54783314e-07]]),
#   array([[ -9.95478907, -14.29507421,   4.20907742, ..., -11.6307948 ,
#            -5.68074566, -10.70519636],
#          [ -9.98813219, -14.9584787 ,   7.64726967, ..., -12.6661741 ,
# ...

# %%
max_len = 50  # 1.25 seconds  # check the timesteps of cqcc and mfcc 
X = []
y = []
i = 0

    
for feat_cqcc, feat_mfcc, label,filename in d:
    cqcc = []
    i+=1
    print(i)
    print('----------------------')
    print(feat_cqcc)
    if type(feat_cqcc) != "<class 'int'>":
        if len(feat_cqcc) > max_len:
            cqcc = feat_cqcc[:max_len]
        elif len(feat_cqcc) < max_len:
            cqcc = np.concatenate((feat_cqcc, np.array([[0.]*num_dim]*(max_len-len(feat_cqcc)))), axis=0)
        X.append(cqcc.reshape(-1))
#         y.append(label,filename)
    #print(data)
# Out:
# 1
# ----------------------
# [[-6.41058952e+02 -6.84246515e+02 -7.16078042e+02 ... -1.33335476e+00
#   -1.35609495e+00 -1.38193288e+00]
#  [ 4.74699924e+00  5.06181341e+00  5.28692289e+00 ... -2.98283630e+00
#   -3.03519820e+00 -3.09488159e+00]
#  [-1.10741354e+01 -1.18301934e+01 -1.24137009e+01 ... -3.89770710e+00
#   -3.96682444e+00 -4.04564951e+00]
#  ...
#  [ 5.47826485e-05  7.46745234e-05  8.74657860e-05 ...  2.18652526e-07
#   -3.54089894e-07 -9.15495513e-07]
#  [-3.14446321e-05 -4.65273964e-05 -5.64856032e-05 ...  2.33922486e-07
#   -3.28666451e-07 -8.80630189e-07]
#  [-7.29279031e-05 -1.01359083e-04 -1.20196691e-04 ...  1.72749807e-07
#   -2.95723008e-07 -7.54783314e-07]]
# 2
# ----------------------
# [[-7.65539388e+02 -8.17110387e+02 -8.55181414e+02 ... -1.48625726e+00
#   -1.51067046e+00 -1.53906893e+00]
#  [ 2.84772000e+01  3.02951103e+01  3.15958747e+01 ... -3.49442577e+00
#   -3.55262663e+00 -3.61996593e+00]
# ...

# %%
d[76][0]
# Out:
# 0

# %%
label_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.dev.trl.txt'

# %%
filename2label = {}
for line in open(label_path):
    line = line.split()
    filename, label = line[1], line[-1]
    filename2label[filename] = label

# %%
#filename2label['LA_D_A3079793']
data = None

# %%
l = pd.read_csv(label_path,delimiter=' ',header=None)
l
# Out:
#              0             1  2    3         4
# 0      LA_0069  LA_D_1047731  -    -  bonafide
# 1      LA_0069  LA_D_1105538  -    -  bonafide
# 2      LA_0069  LA_D_1125976  -    -  bonafide
# 3      LA_0069  LA_D_1293230  -    -  bonafide
# 4      LA_0069  LA_D_1340209  -    -  bonafide
# ...        ...           ... ..  ...       ...
# 24839  LA_0078  LA_D_9924204  -  A06     spoof
# 24840  LA_0078  LA_D_9931163  -  A06     spoof
# 24841  LA_0078  LA_D_9935163  -  A06     spoof
# 24842  LA_0078  LA_D_9944718  -  A06     spoof
# 24843  LA_0078  LA_D_9967770  -  A06     spoof
#
# [24844 rows x 5 columns]

# %%
l.loc[l[1] == 'LA_D_A307979']
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4]
# Index: []

# %%
l[1]
# Out:
# 0        LA_D_1047731
# 1        LA_D_1105538
# 2        LA_D_1125976
# 3        LA_D_1293230
# 4        LA_D_1340209
#              ...
# 24839    LA_D_9924204
# 24840    LA_D_9931163
# 24841    LA_D_9935163
# 24842    LA_D_9944718
# 24843    LA_D_9967770
# Name: 1, Length: 24844, dtype: object

# %%
train_data_path = '/Users/asimadnan/Desktop/Mres/Experiments/testfiles/04-04-2021_15-57_la_train_cqcc.csv'
train_label_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.train.trn.txt'

# %%
train_data = pd.read_csv(train_data_path, delimiter = ",",index_col=0)
train_labels = pd.read_csv(train_label_path, delimiter = " ", header=None)
train_labels.columns = ['SPEAKER_ID','AUDIO_FILE_NAME','ENVIRONMENT_ID','ATTACK_ID','KEY']

# %%
train_data.columns
train_data = train_data.rename({'3001': 'AUDIO_FILE_NAME'}, axis=1)  # new method
train_data.head()
# Out:
#             0           1           2           3           4           5  \
# 0 -464.155181 -495.522679 -518.669731 -533.490287 -540.352053 -540.052042
# 1 -438.159132 -468.049546 -490.248496 -504.652483 -511.602940 -511.844624
# 2 -462.670195 -493.807073 -516.782161 -531.504245 -538.351898 -538.128277
# 3 -794.036712 -847.401284 -886.737284 -911.896149 -923.538541 -923.056072
# 4 -651.217753 -694.968951 -727.233868 -747.892355 -757.485662 -757.152130
#
#             6           7           8           9  ...      2992      2993  \
# 0 -533.743179 -522.838269 -508.899784 -493.522522  ...  0.006584  0.004693
# 1 -506.456774 -496.762917 -484.227285 -470.344481  ...  0.000162  0.000178
# 2 -531.987350 -521.337874 -507.733552 -492.756440  ... -0.000626 -0.000665
# 3 -912.443741 -894.133935 -870.806630 -845.187975  ... -0.000760 -0.002014
# 4 -748.522678 -733.585020 -714.528550 -693.579898  ... -0.000504 -0.000635
#
# ...

# %%
train_labels.head()
# Out:
#   SPEAKER_ID AUDIO_FILE_NAME ENVIRONMENT_ID ATTACK_ID       KEY
# 0    LA_0079    LA_T_1138215              -         -  bonafide
# 1    LA_0079    LA_T_1271820              -         -  bonafide
# 2    LA_0079    LA_T_1272637              -         -  bonafide
# 3    LA_0079    LA_T_1276960              -         -  bonafide
# 4    LA_0079    LA_T_1341447              -         -  bonafide

# %%
merged_data = pd.merge(train_data, train_labels, on='AUDIO_FILE_NAME')
merged_data
# Out:
#                 0           1           2           3           4           5  \
# 0     -464.155181 -495.522679 -518.669731 -533.490287 -540.352053 -540.052042
# 1     -438.159132 -468.049546 -490.248496 -504.652483 -511.602940 -511.844624
# 2     -462.670195 -493.807073 -516.782161 -531.504245 -538.351898 -538.128277
# 3     -794.036712 -847.401284 -886.737284 -911.896149 -923.538541 -923.056072
# 4     -651.217753 -694.968951 -727.233868 -747.892355 -757.485662 -757.152130
# ...           ...         ...         ...         ...         ...         ...
# 25375 -495.207170 -528.624470 -553.325262 -569.209968 -576.680890 -576.593907
# 25376 -550.896460 -588.071105 -615.503826 -633.074891 -641.226714 -640.911057
# 25377 -512.088485 -546.864343 -572.579667 -589.099351 -596.809765 -596.571347
# 25378 -420.361134 -448.704791 -469.608067 -482.982316 -489.168372 -488.895819
# 25379 -558.422234 -595.639269 -622.965947 -640.308140 -648.139314 -647.444803
#
# ...

# %%
X = merged_data.iloc[:, 0:3001]
X
# Out:
#                 0           1           2           3           4           5  \
# 0     -464.155181 -495.522679 -518.669731 -533.490287 -540.352053 -540.052042
# 1     -438.159132 -468.049546 -490.248496 -504.652483 -511.602940 -511.844624
# 2     -462.670195 -493.807073 -516.782161 -531.504245 -538.351898 -538.128277
# 3     -794.036712 -847.401284 -886.737284 -911.896149 -923.538541 -923.056072
# 4     -651.217753 -694.968951 -727.233868 -747.892355 -757.485662 -757.152130
# ...           ...         ...         ...         ...         ...         ...
# 25375 -495.207170 -528.624470 -553.325262 -569.209968 -576.680890 -576.593907
# 25376 -550.896460 -588.071105 -615.503826 -633.074891 -641.226714 -640.911057
# 25377 -512.088485 -546.864343 -572.579667 -589.099351 -596.809765 -596.571347
# 25378 -420.361134 -448.704791 -469.608067 -482.982316 -489.168372 -488.895819
# 25379 -558.422234 -595.639269 -622.965947 -640.308140 -648.139314 -647.444803
#
# ...

# %%
y = merged_data.iloc[:, 3000:3001]
y
# Out:
#            3000
# 0         spoof
# 1         spoof
# 2         spoof
# 3         spoof
# 4         spoof
# ...         ...
# 25375     spoof
# 25376     spoof
# 25377  bonafide
# 25378     spoof
# 25379     spoof
#
# [25380 rows x 1 columns]

# %%
bondata = X.loc[X['3000'] == 'bonafide']
spoofdata = X.loc[X['3000'] == 'spoof']

# %%
bondata = bondata.iloc[:, 0:3000]
spoofdata = spoofdata.iloc[:, 0:3000]

# %%
bondata
# Out:
#                 0           1           2           3           4           5  \
# 6     -677.696398 -723.737009 -757.867726 -779.938740 -790.488072 -790.676369
# 17    -565.718124 -603.679097 -631.687739 -649.644329 -658.020662 -657.803903
# 19    -524.186007 -559.462201 -585.479174 -602.133811 -609.856579 -609.560192
# 54    -609.460018 -650.334814 -680.459668 -699.730242 -708.662382 -708.331478
# 67    -675.100882 -720.134938 -753.306617 -774.526286 -784.386290 -784.091671
# ...           ...         ...         ...         ...         ...         ...
# 25359 -356.526038 -380.584598 -398.334767 -409.699000 -414.963293 -414.742777
# 25367 -594.098375 -633.953979 -663.307279 -682.044271 -690.655175 -690.176252
# 25370 -543.510368 -580.115254 -607.107618 -624.377156 -632.368108 -632.026326
# 25373 -575.397990 -614.142944 -642.734744 -661.057411 -669.579340 -669.297286
# 25377 -512.088485 -546.864343 -572.579667 -589.099351 -596.809765 -596.571347
#
# ...

# %%
gmm_bon = GMM(n_components = 144, covariance_type='diag',n_init = 50,verbose=1) # min shape[0] = 135 # max = 1112
#gmm_sp  = GMM(n_components = 144, covariance_type='diag',n_init = 50,verbose=1)  # min shape[0] = 64  # max = 1318

# %%
t0 = time.time()
gmm_bon.fit(bondata)
print('Bon gmm trained, time spend:', time.time() - t0)
pickle.dump(gmm_bon, open(output_path + current_time +'_bon_train' + '.gmm', 'wb'))


t0 = time.time()
gmm_sp.fit(spoofdata,verbose=1)
print('Sp gmm trained, time spend:', time.time() - t0)
# Out:
# Initialization 0
#   Iteration 10
# Initialization converged: True
# Initialization 1
#   Iteration 10
# Initialization converged: True
# Initialization 2
#   Iteration 10
# Initialization converged: True
# Initialization 3
#   Iteration 10
# Initialization converged: True
# Initialization 4
#   Iteration 10
#   Iteration 20
# Initialization converged: True
# Initialization 5
#   Iteration 10
# Initialization converged: True
# Initialization 6
#   Iteration 10
# Initialization converged: True
# Initialization 7
#   Iteration 10
# Initialization converged: True
# Initialization 8
#   Iteration 10
# Initialization converged: True
# Initialization 9
#   Iteration 10
# Initialization converged: True
# Initialization 10
#   Iteration 10
# Initialization converged: True
# Initialization 11
#   Iteration 10
#   Iteration 20
# Initialization converged: True
# Initialization 12
#   Iteration 10
# Initialization converged: True
# Initialization 13
#   Iteration 10
# ...

# %%
pickle.dump(gmm_bon, open('/Users/asimadnan/Desktop/Mres/Experiments/testfiles/cqcc_bon.gmm', 'wb'))
pickle.dump(gmm_sp, open('/Users/asimadnan/Desktop/Mres/Experiments/testfiles/cqcc_spoof.gmm', 'wb'))

# %%
data_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/output_data/test__mfcc.csv'
#data_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/output_data/test__cqcc.csv'
label_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.dev.trl.txt'

# %%
bon_model_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/output_data/train_mfcc_bon.gmm'
spf_model_path = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/output_data/train_mfcc_spoof.gmm'

gmm_bon = pickle.load(open(bon_model_path,'rb'))
gmm_sp  = pickle.load(open(spf_model_path,'rb'))

# %%
svm = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/output_data/svm_model__mfcc.svm'
svm_model = pickle.load(open(svm,'rb'))

# %%
# function to read cqcc/mfcc data from devset

def extract_data(data_path,label_path,feature_type):
    data_set = pd.read_csv(data_path, delimiter = ",",index_col=0)
    labels = pd.read_csv(label_path, delimiter = " ", header=None)
    labels.columns = ['SPEAKER_ID','AUDIO_FILE_NAME','ENVIRONMENT_ID','ATTACK_ID','KEY']

    feature_len = 650

    if (feature_type == 'cqcc'):
        feature_len = 3000

    
    data_set = data_set.rename({str(feature_len + 1): 'AUDIO_FILE_NAME'}, axis=1)
    data_set = pd.merge(data_set, labels, on='AUDIO_FILE_NAME')
    
    #bondata = data_set.loc[data_set[str(feature_len)] == 'bonafide']
    #spoofdata = data_set.loc[data_set[str(feature_len)] == 'spoof']
    #bondata = bondata.iloc[:, 0:feature_len]
    #spoofdata = spoofdata.iloc[:, 0:feature_len]

    return data_set.iloc[:, 0:feature_len].values,data_set.iloc[:, feature_len+1:data_set.shape[1]]

# %%
feature = 'mfcc'
raw_data,labels = extract_data(data_path,label_path,feature)

# %%
y_score = svm_model.decision_function(raw_data)
labels[['SCORE']] = y_score
labels[['AUDIO_FILE_NAME','ATTACK_ID','KEY','SCORE']]
# Out:
#   AUDIO_FILE_NAME ATTACK_ID       KEY     SCORE
# 0    LA_D_1099405       A02     spoof  2.479977
# 1    LA_D_9330492         -  bonafide -0.583404
# 2    LA_D_1364611         -  bonafide -0.824405
# 3    LA_D_3986002         -  bonafide -0.690101
# 4    LA_D_3411825       A03     spoof  1.930599
# 5    LA_D_8173305       A02     spoof  2.611139
# 6    LA_D_6027798         -  bonafide -0.161713

# %%
feature_type = 'mfcc'
data_set = pd.read_csv(data_path, delimiter = ",",index_col=0)
labels = pd.read_csv(label_path, delimiter = " ", header=None)
labels.columns = ['SPEAKER_ID','AUDIO_FILE_NAME','ENVIRONMENT_ID','ATTACK_ID','KEY']

feature_len = 650

if (feature_type == 'cqcc'):
    feature_len = 3000


data_set = data_set.rename({str(feature_len + 1): 'AUDIO_FILE_NAME'}, axis=1)
data_set = pd.merge(data_set, labels, on='AUDIO_FILE_NAME')

# %%
raw_data,labels = extract_data(data_path,label_path,'mfcc')

# %%
predic_scores = []
j_bon = len(raw_data)

for i in range(j_bon):
    if (i % 50 == 0):
        print('Evaluating Bon sample at',i/j_bon * 100, '%')
    X = [raw_data[i]]
    bscore = gmm_bon.score(X)
    sscore = gmm_sp.score(X)

    #predic_scores.append(np.exp(bscore)-np.exp(sscore))
    predic_scores.append(bscore-sscore)
# Out:
# Evaluating Bon sample at 0.0 %

# %%
predic_scores
# Out:
# [-2052.911184395618,
#  126.621581905614,
#  101.09534189472629,
#  -51.040092679055306,
#  -1171.9821914280747,
#  -2118.34990401748,
#  61.51150154629477]

# %%
labels[['SCORE']] = predic_scores
labels[['AUDIO_FILE_NAME','ATTACK_ID','KEY','SCORE']]
# Out:
#   AUDIO_FILE_NAME ATTACK_ID       KEY        SCORE
# 0    LA_D_1099405       A02     spoof -2052.911184
# 1    LA_D_9330492         -  bonafide   126.621582
# 2    LA_D_1364611         -  bonafide   101.095342
# 3    LA_D_3986002         -  bonafide   -51.040093
# 4    LA_D_3411825       A03     spoof -1171.982191
# 5    LA_D_8173305       A02     spoof -2118.349904
# 6    LA_D_6027798         -  bonafide    61.511502

# %%
def combine_scores(predic_scores,la):
    labels[['SCORE']] = predic_scores
    labels[['AUDIO_FILE_NAME','ATTACK_ID','KEY','SCORE']]

# %%
final_score = combine_scores(predic_scores,label_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-3929c654037e> in <module>
# ----> 1 final_score = combine_scores(predic_scores,label_path)
#
# <ipython-input-86-20e1583db901> in combine_scores(predic_scores, label_path)
#       2     labels = pd.read_csv(label_path, delimiter = " ", header=None)
#       3     labels.columns = ['SPEAKER_ID','AUDIO_FILE_NAME','ENVIRONMENT_ID','ATTACK_ID','KEY']
# ----> 4     labels[['SCORE']] = predic_scores
#       5     return labels[['AUDIO_FILE_NAME','ATTACK_ID','KEY','SCORE']]
#       6
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3035             self._setitem_frame(key, value)
#    3036         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3037             self._setitem_array(key, value)
#    3038         else:
# ...

# %%
final_score

# %%
data_set = pd.read_csv(data_path, delimiter = ",",index_col=0)
labels = pd.read_csv(label_path, delimiter = " ", header=None)
labels.columns = ['SPEAKER_ID','AUDIO_FILE_NAME','ENVIRONMENT_ID','ATTACK_ID','KEY']

data_set = data_set.rename({'3001': 'AUDIO_FILE_NAME'}, axis=1)
data_set = pd.merge(data_set, labels, on='AUDIO_FILE_NAME')

# %%
dev_set = data_set.iloc[:, 0:3000]

# %%
preds = []
dev_len = len(dev_set)

# %%
for i in range(dev_len):
    if (i % 50 == 0):
        print('Evaluating Bon sample at',i/dev_len * 100, '%')
    X = [dev_set.values[i]]
    bscore = gmm_bon.score(X)
    sscore = gmm_sp.score(X)

    #predb.append(np.exp(bscore)-np.exp(sscore))
    preds.append(bscore-sscore)
# Out:
# Evaluating Bon sample at 0.0 %
# Evaluating Bon sample at 0.20125583641925618 %
# Evaluating Bon sample at 0.40251167283851236 %
# Evaluating Bon sample at 0.6037675092577685 %
# Evaluating Bon sample at 0.8050233456770247 %
# Evaluating Bon sample at 1.0062791820962809 %
# Evaluating Bon sample at 1.207535018515537 %
# Evaluating Bon sample at 1.4087908549347932 %
# Evaluating Bon sample at 1.6100466913540494 %
# Evaluating Bon sample at 1.8113025277733052 %
# Evaluating Bon sample at 2.0125583641925617 %
# Evaluating Bon sample at 2.213814200611818 %
# Evaluating Bon sample at 2.415070037031074 %
# Evaluating Bon sample at 2.61632587345033 %
# Evaluating Bon sample at 2.8175817098695863 %
# Evaluating Bon sample at 3.0188375462888426 %
# Evaluating Bon sample at 3.220093382708099 %
# Evaluating Bon sample at 3.4213492191273542 %
# Evaluating Bon sample at 3.6226050555466105 %
# Evaluating Bon sample at 3.8238608919658668 %
# Evaluating Bon sample at 4.0251167283851235 %
# ...

# %%
preds = np.asarray(preds)

# %%
y = data_set[['AUDIO_FILE_NAME','KEY','ATTACK_ID']]

# %%
y[['SCORE']] = preds
# Out:
# /Users/asimadnan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:659: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[k] = np.nan
# <ipython-input-123-05b82d1ebdbe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[['SCORE']] = preds
# /Users/asimadnan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
y = y[['AUDIO_FILE_NAME','ATTACK_ID','KEY','SCORE']]

# %%
y.to_csv('cqcc_scores.csv',index=False,sep=" ",header=False)
y
# Out:
#       AUDIO_FILE_NAME ATTACK_ID    KEY        SCORE
# 0        LA_D_2776056       A03  spoof  -960.641302
# 1        LA_D_8676372       A06  spoof  -833.470539
# 2        LA_D_4086358       A03  spoof  -516.075607
# 3        LA_D_4407621       A05  spoof -1815.230974
# 4        LA_D_6154817       A06  spoof   567.589669
# ...               ...       ...    ...          ...
# 24839    LA_D_8379770       A04  spoof    16.694905
# 24840    LA_D_7522206       A03  spoof -2093.087034
# 24841    LA_D_7830688       A06  spoof -1380.746102
# 24842    LA_D_3449140       A04  spoof -2172.918086
# 24843    LA_D_7447967       A02  spoof  -743.067959
#
# [24844 rows x 4 columns]

# %%
asv_score_file = '/Users/asimadnan/Desktop/Mres/ASVSPOOF_DATA/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.dev.trl.txt'
cm_score_file = '/Users/asimadnan/Desktop/Mres/Experiments/cqcc_scores.csv'

# %%
cm_score_file = '/Users/asimadnan/Desktop/Mres/Experiments/Models/25-03-2021_11-54svm_cm_score.txt'
cm_data = np.genfromtxt(cm_score_file, dtype=str)
cm_data
# Out:
# array([['LA_E_7338223', 'A07', 'spoof', '2.0372507702936598'],
#        ['LA_E_9469091', 'A10', 'spoof', '2.6736848260692936'],
#        ['LA_E_1788336', 'A07', 'spoof', '2.547469351774194'],
#        ...,
#        ['LA_E_6825673', 'A08', 'spoof', '2.990277743151539'],
#        ['LA_E_7894529', 'A16', 'spoof', '2.402580317154648'],
#        ['LA_E_6723023', 'A07', 'spoof', '2.5576326858327225']],
#       dtype='<U22')

# %%
# Out:
#             KEY
# 0         spoof
# 1         spoof
# 2         spoof
# 3         spoof
# 4         spoof
# ...         ...
# 25375     spoof
# 25376     spoof
# 25377  bonafide
# 25378     spoof
# 25379     spoof
#
# [25380 rows x 1 columns]

# %%
from sklearn.svm import SVC
svm = SVC(probability=True,verbose=1)
svm.fit(merged_data.iloc[:, 0:3000].values, merged_data.iloc[:, 3005:30006].values)
# Out:
# /Users/asimadnan/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [LibSVM]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-b988666e0f44> in <module>
#       1 from sklearn.svm import SVC
#       2 svm = SVC(probability=True,verbose=1)
# ----> 3 svm.fit(merged_data.iloc[:, 0:3000], merged_data.iloc[:, 3005:30006])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     215
#     216         seed = rnd.randint(np.iinfo('i').max)
# --> 217         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     218         # see comment on the other call to np.iinfo in this file
#     219
#
# ...
